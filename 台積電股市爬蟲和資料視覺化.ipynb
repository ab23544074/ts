# %%
# 爬蟲

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://goodinfo.tw/StockInfo/StockBzPerformance.asp?STOCK_ID=2330'
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

# %%
res = requests.get(url,headers = headers)
res.encoding= 'uft-8'

# %%
soup = BeautifulSoup(res.text,'lxml')

# %%
data= soup.select_one('#txtFinDetailData')

# %%
import pandas
dfa = pandas.read_html(data.prettify())
dfa=dfa[1]

# %%
dfa.columns  = dfa.columns.get_level_values(3)

# %%
dfa.columns
# Out:
# Index(['年度', '股本  (億)', '財報  評分', '收盤', '平均', '漲跌', '漲跌  (%)', '營業  收入',
#        '營業  毛利', '營業  利益', '業外  損益', '稅後  淨利', '營業  毛利', '營業  利益', '業外  損益',
#        '稅後  淨利', 'ROE  (%)', 'ROA  (%)', '稅後  EPS', '年增  (元)', 'BPS  (元)'],
#       dtype='object')

# %%
dfa.drop(columns=['業外  損益','業外  損益', '年增  (元)', 'BPS  (元)'])
# Out:
#       年度 股本  (億) 財報  評分     收盤    平均      漲跌 漲跌  (%) 營業  收入 營業  毛利 營業  利益  \
# 0   20Q2    2593     96    460   347    +129     +39   6213   3254   2596
# 1   2019    2593     89    331   262  +105.5   +46.8  10700   4927   3727
# 2   2018    2593     94  225.5   237      -4    -1.7  10315   4979   3836
# 3   2017    2593     91  229.5   210     +48   +26.4   9774   4948   3856
# 4   2016    2593     91  181.5   166   +38.5   +26.9   9479   4748   3780
# 5   2015    2593     94    143   140      +2    +1.4   8435   4104   3200
# 6   2014    2593     91    141   123   +35.5   +33.6   7628   3777   2959
# 7   2013    2593     89  105.5   104    +8.5    +8.8   5970   2809   2094
# 8   2012    2592     89     97  84.1   +21.2     +28   5067   2441   1812
# 9   2011    2592     94   75.8  72.1    +4.8    +6.8   4271   1941   1416
# 10  2010    2591     96     71    62    +6.5   +10.1   4195   2071   1592
# 11  2009    2590     91   64.5  55.5   +20.1   +45.3   2957   1293    920
# 12  2008    2563     94   44.4  56.4   -17.6   -28.4   3332   1417   1044
# 13  2007    2643     94     62  65.5    -5.5    -8.1   3226   1424   1117
# 14  2006    2583     96   67.5  61.3      +5      +8   3174   1558   1273
# 15  2005    2473     94   62.5  54.1     +12   +23.8   2666   1182    910
# 16  2004    2325     89   50.5  52.4     -13   -20.5   2572   1158    885
# 17  2003    2027     79   63.5  56.4   +20.9   +49.1   2030    749    513
# 18  2002    1862     66   42.6  67.4   -44.9   -51.3   1623    523    316
# 19  2001    1683     60   87.5  77.7      +9   +11.5   1259    337    128
# 20  2000    1169     91   78.5   147   -88.5     -53   1662    786    613
# 21  1999     852     74    167   120     +96    +135    763    301    223
# 22  1998     605     72     71   101     -41   -36.6    504    181    138
# 23  1997     408     83    112   109   +55.5   +98.2    439    211    149
# 24  1996     265     94   56.5  63.8   -28.5   -33.5    394    220    182
# 25  1995     144     91     85   128     -72   -45.9    288    161    139
# 26  1994      78      -    157   159     +61   +63.5      -      -      -
# 27  1993       -      -      -     -       -       -      -      -      -
# 28  1992       -      -      -     -       -       -      -      -      -
# 29  1991       -      -      -     -       -       -      -      -      -
#
#    稅後  淨利 營業  毛利 營業  利益 稅後  淨利    ROE  (%)    ROA  (%) 稅後  EPS
# 0    2378   52.4   41.8   38.3  28.5  (年估)  20.2  (年估)    9.17
# 1    3453     46   34.8   32.3        20.9        15.9   13.32
# 2    3511   48.3   37.2     34        21.9        17.2   13.54
# 3    3431   50.6   39.4   35.1        23.6        17.7   13.23
# 4    3342   50.1   39.9   35.3        25.6        18.9   12.89
# 5    3066   48.7   37.9   36.3          27        19.4   11.82
# 6    2639   49.5   38.8   34.6        27.9        19.1   10.18
# 7    1881   47.1   35.1   31.5        23.9        16.9    7.26
# 8    1663   48.2   35.8   32.8        24.5        19.1    6.42
# 9    1342   45.5   33.1   31.5        22.2          18    5.18
# 10   1616   49.4   37.9   38.7        30.1        24.7    6.24
# 11    892   43.7   31.1   30.3        18.3        15.5    3.45
# 12    999   42.5   31.3   30.2        20.7        17.8    3.86
# 13   1092   44.1   34.6   34.1          22          19    4.14
# 14   1270   49.1   40.1   40.1        26.6          23    4.93
# 15    936   44.3   34.1   35.1        22.2        18.4    3.79
# 16    923     45   34.4   35.9        25.4        20.4    3.97
# 17    473   36.9   25.3   23.3        15.1        11.8    2.33
# 18    216   32.2   19.5   13.3        7.54        5.71    1.14
# 19    145   26.7   10.2   11.5        5.37        3.93    0.83
# 20    651   47.3   36.9   39.2        31.4        21.5    5.71
# 21    235   39.4   29.2   30.8        19.9        12.5    3.24
# 22    153     36   27.4   30.4          20        11.6    2.54
# 23    180     48     34   40.9        29.6        17.7     4.4
# 24    194   55.8   46.3   49.2        45.3        30.5    7.31
# 25    151     56   48.3   52.4        44.9        31.2   10.48
# 26   84.7      -      -      -           -           -   10.86
# 27      -      -      -      -           -           -       -
# 28      -      -      -      -           -           -       -
# 29      -      -      -      -           -           -       -

# %%
type(dfa)
# Out:
# pandas.core.frame.DataFrame

# %%
#載入畫圖套件
import matplotlib
import matplotlib.pyplot as plt

# %%
#把資料轉為數值型態，不然plot排序會出問題

dfa['財報  評分'] = pandas.to_numeric(dfa['財報  評分'],errors='coerce')
print(type(dfa['財報  評分']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
fig = plt.figure()
#調整大小
plt.figure(figsize=(22,4))
plt.xticks(fontsize=16)

plt.plot(dfa['年度'],dfa['財報  評分'])

#更改年度排序(由小到大)
plt.gca().invert_xaxis()
#文字標籤
plt.xlabel("年度",fontsize=20)
plt.ylabel("評分",fontsize=18)
plt.title("台積電每年度財報評分",fontsize=20)
#顯示中文字
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False

plt.show()

# %%
#seaborn 
import seaborn as sns

# %%
dfa['稅後  EPS'] = pandas.to_numeric(dfa['稅後  EPS'],errors='coerce')
print(type(dfa['稅後  EPS']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
fig = plt.figure()
plt.figure(figsize=(22,8))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(dfa['年度'],dfa['稅後  EPS'])
plt.gca().invert_xaxis()
#文字標籤
plt.xlabel("年度",fontsize=20)
plt.ylabel("稅後 EPS",fontsize=18)
plt.title("台積電每年度稅後 EPS",fontsize=20)
#顯示中文字
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False
